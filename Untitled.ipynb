# %%
...
A : 100 - 80
B : 79 - 70
C : 69 - 60
D : 59 - 50
E : 49 - 0
...


score = int(input("Enter your score : "))
if score >= 80:
    print("grade A ")
elif score >=70:
    print("grade B ")
elif score >=60:
    print("grade C ")
elif score >=50:
    print("grade D ")
else:
    print("grade E ")

try :
    score = int(input("enter score : "))

except :
     print("error value")
# Out:
# Enter your score :  20
# grade E
# enter score :  c
# error value

# %%
num = int(input("input number: "))

if num % 2 == 0:
    print("odd")
else:
    print("even")
# Out:
# input number:  3
# even
