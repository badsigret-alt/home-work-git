# %%
class person:
def _init_(self, cid, name, lname):
    self.cid = cid
    self.namme = name
    self.lname = lname 
    def info(self):
        print("{} {} {}".format(self.cid, self.name, self.lname))
# Out:
#   Cell In[5], line 2
#     def _init_(self, cid, name, lname):
#     ^
# IndentationError: expected an indented block after class definition on line 1
